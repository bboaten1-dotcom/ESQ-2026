# %% [markdown]
# # Week 2 — Heart Disease Research Project
# ## Student Starter Notebook
#
# This is your independent research notebook.
#
# You already practiced the full workflow with the Penguin Random Forest + SHAP notebook. Now you will apply the same workflow to the Heart Disease dataset.
#
# **Research question**
#
# > Can a Random Forest model predict whether a patient has heart disease, and which clinical features explain the model's predictions?
#
# **Your workflow**
#
# `Load data → Clean data → Explore data → Create X and y → Train/test split → Train Random Forest → Evaluate → Inspect wrong predictions → Explain with SHAP → Write discussion`

# %% [markdown]
# ## 0. Setup — run this cell first
#
# This cell imports the tools you need. You do not need to change it.

# %%
# Install SHAP only if it is not already available.
import importlib.util
import sys
import subprocess

if importlib.util.find_spec("shap") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "shap", "--quiet"])

import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    ConfusionMatrixDisplay
)

import shap

sns.set_style("whitegrid")
print("All tools ready ✅")

# %% [markdown]
# ## 1. Load the dataset
#
# Run this cell to load the Cleveland Heart Disease dataset.
#
# Each row is one patient. Each column is a clinical feature or diagnosis value.

# %%
cols = [
    "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
    "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"
]

uci_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
github_url = "https://raw.githubusercontent.com/StatQuest/logistic_regression_demo/master/processed.cleveland.data"

try:
    df = pd.read_csv(uci_url, names=cols, na_values="?")
except Exception:
    df = pd.read_csv(github_url, names=cols, na_values="?")

print(f"Loaded {df.shape[0]} patients and {df.shape[1]} columns.")
df.head()

# %% [markdown]
# ## 2. Feature guide
#
# Run this cell to understand what the columns mean.

# %%
feature_info = pd.DataFrame([
    ("age",      "Age in years"),
    ("sex",      "Sex (1 = male, 0 = female)"),
    ("cp",       "Chest pain type (1 typical angina, 2 atypical, 3 non-anginal, 4 asymptomatic)"),
    ("trestbps", "Resting blood pressure in mm Hg"),
    ("chol",     "Serum cholesterol in mg/dl"),
    ("fbs",      "Fasting blood sugar > 120 mg/dl (1 = true, 0 = false)"),
    ("restecg",  "Resting ECG result"),
    ("thalach",  "Maximum heart rate achieved"),
    ("exang",    "Exercise-induced angina (1 = yes, 0 = no)"),
    ("oldpeak",  "ST depression induced by exercise relative to rest"),
    ("slope",    "Slope of the peak exercise ST segment"),
    ("ca",       "Number of major vessels colored by fluoroscopy"),
    ("thal",     "Thalassemia result (3 normal, 6 fixed defect, 7 reversible defect)"),
    ("num",      "Original diagnosis: 0 = no disease, 1-4 = disease present")
], columns=["Feature", "Meaning"])

feature_info

# %% [markdown]
# # Your independent analysis starts here
#
# Use the Penguin notebook as your model. Complete each section yourself.

# %% [markdown]
# ## 3. Inspect and clean the data
#
#
# Check:
# - dataset shape,
# - column names,
# - missing values,
# - rows with missing values.
#
# Then clean the dataset by removing or handling missing values.

# %%
# YOUR CODE HERE
# Suggested steps:
# 1. Check df.shape
# 2. Check df.isnull().sum()
# 3. Drop rows with missing values if needed
# 4. Confirm the cleaned shape

# %% [markdown]
# ## 4. Create the binary target variable
#
#
# Convert the original `num` column into a binary target:
# - 0 = No disease
# - 1 = Disease
#
# Create a readable target label column for plotting.

# %%
# YOUR CODE HERE
# Hint:
# df["target"] = ...
# df["target_label"] = ...
# Check value_counts()

# %% [markdown]
# ## 5. EDA: target distribution
#
#
# Make a plot showing how many patients are in each target class.
#
# Research question:
# > Is the dataset balanced or imbalanced?

# %%
# YOUR CODE HERE
# Create a count plot or bar plot of the target classes.

# %% [markdown]
# ## 6. EDA: input feature distributions
#
#
# Choose important numerical features such as:
# - age
# - trestbps
# - chol
# - thalach
# - oldpeak
#
# Create histograms to understand their distributions.

# %%
# YOUR CODE HERE
# Use histograms for several numerical input features.

# %% [markdown]
# ## 7. EDA: input features by target class
#
#
# Compare numerical features between patients with and without disease.
#
# Research question:
# > Which features appear different between the two classes?

# %%
# YOUR CODE HERE
# Use class-based histograms and/or box plots.

# %% [markdown]
# ## 8. EDA: relationships among features
#
#
# Create:
# - one scatter plot using two important features,
# - one correlation heatmap.
#
# Research question:
# > Which features are related to each other?

# %%
# YOUR CODE HERE
# Use a scatter plot and a correlation heatmap.

# %% [markdown]
# ## 9. Prepare X and y
#
#
# Create:
# - `X`: input features
# - `y`: target label
#
# Use the 13 clinical features as inputs.

# %%
# YOUR CODE HERE
# Suggested feature columns:
# ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
#  "thalach", "exang", "oldpeak", "slope", "ca", "thal"]

# %% [markdown]
# ## 10. Train-test split
#
#
# Split the data into training and test sets.
#
# Use stratification so both sets have similar target balance.

# %%
# YOUR CODE HERE
# Use train_test_split

# %% [markdown]
# ## 11. Train the Random Forest
#
#
# Train a Random Forest classifier.
#
# Report:
# - model name,
# - number of trees,
# - random_state.

# %%
# YOUR CODE HERE
# Create RandomForestClassifier
# Fit the model
# Predict on X_test

# %% [markdown]
# ## 12. Evaluate the model
#
#
# Calculate:
# - accuracy,
# - precision,
# - recall,
# - F1-score,
# - classification report,
# - confusion matrix.
#
# Research question:
# > What kind of errors did the model make?

# %%
# YOUR CODE HERE
# Calculate metrics and plot confusion matrix.

# %% [markdown]
# ## 13. Inspect actual vs predicted cases
#
#
# Create a table showing:
# - X_test features,
# - actual y,
# - predicted y,
# - actual class,
# - predicted class,
# - model probability,
# - correct/wrong result.
#
# Then inspect:
# - wrong predictions only,
# - least confident predictions.

# %%
# YOUR CODE HERE
# Build a prediction_results table.

# %% [markdown]
# ## 14. Explain the model with SHAP
#
#
# Use SHAP to explain the trained Random Forest.
#
# Create:
# - SHAP bar plot,
# - SHAP beeswarm plot,
# - one SHAP waterfall plot.
#
# Research question:
# > Which features influenced the model most, and how?

# %%
# YOUR CODE HERE
# Create TreeExplainer and SHAP plots.

# %% [markdown]
# ## 15. Discussion prompts
#
#
# Answer these in markdown:
#
# 1. Which features appeared important during EDA?
# 2. How well did the model perform?
# 3. What kinds of errors did the model make?
# 4. Which features were most important in SHAP?
# 5. Did SHAP agree with the EDA?
# 6. Why are false negatives important in a medical prediction problem?

# %%
# Write your discussion below in markdown, not code.

# %% [markdown]
# # Final reminder
#
# Do not only report code outputs. Interpret what the outputs mean.
#
# Your final paper should connect:
#
# > EDA → Model performance → Wrong predictions → SHAP explanation → Research conclusion
